# %%
#dependencies and setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

#api key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

#output CSV
output_data_file = "output_data_cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
 # List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 603

# %%
#lists for storage
responses = []
city_id = []
city_name = []
cloud = []
country = []
date = []
hum = []
lat = []
lng = []
max_temp = []
wind_speed = []

r_num = 1
#build url and query_url
url = "http://api.openweathermap.org/data/2.5/weather?"
for city in cities:
    try:
        query_url = url + "appid=" + api_key + "&q=" + city
        weather_data = requests.get(query_url)
        city_name.append(weather_data.json()['name'])
        cloud.append(weather_data.json()['clouds']['all'])
        country.append(weather_data.json()['sys']['country'])
        date.append(weather_data.json()['dt'])
        hum.append(weather_data.json()['main']['humidity'])
        lat.append(weather_data.json()['coord']['lat'])
        lng.append(weather_data.json()['coord']['lon'])
        max_temp.append(weather_data.json()['main']['temp_max'])
        wind_speed.append(weather_data.json()['wind']['speed'])
        print(f"Processing request number {r_num}:{city}")
        r_num = r_num + 1
    except KeyError:
        print("city not found. skipping...")
# Out:
# city not found. skipping...
# city not found. skipping...
# Processing request number 1:bluff
# Processing request number 2:berdigestyakh
# Processing request number 3:punta arenas
# Processing request number 4:torbay
# city not found. skipping...
# Processing request number 5:mar del plata
# Processing request number 6:port alfred
# Processing request number 7:mae sai
# city not found. skipping...
# Processing request number 8:vaini
# Processing request number 9:jamestown
# Processing request number 10:trairi
# Processing request number 11:kavieng
# Processing request number 12:valparaiso
# Processing request number 13:saint-philippe
# Processing request number 14:rikitea
# Processing request number 15:coihaique
# Processing request number 16:busselton
# Processing request number 17:dudinka
# Processing request number 18:faanui
# Processing request number 19:hermanus
# Processing request number 20:kodiak
# Processing request number 21:grand gaube
# Processing request number 22:toamasina
# Processing request number 23:vila velha
# Processing request number 24:prince rupert
# Processing request number 25:mocuba
# Processing request number 26:mataura
# Processing request number 27:palu
# Processing request number 28:maningrida
# Processing request number 29:mahebourg
# Processing request number 30:lompoc
# Processing request number 31:esperance
# Processing request number 32:hithadhoo
# Processing request number 33:atuona
# Processing request number 34:lebu
# Processing request number 35:talnakh
# Processing request number 36:kisangani
# Processing request number 37:tessalit
# Processing request number 38:shingu
# Processing request number 39:waingapu
# Processing request number 40:yulara
# Processing request number 41:tuatapere
# Processing request number 42:sur
# Processing request number 43:albany
# Processing request number 44:bronnoysund
# Processing request number 45:ushuaia
# Processing request number 46:dikson
# city not found. skipping...
# Processing request number 47:selenduma
# city not found. skipping...
# Processing request number 48:iqaluit
# Processing request number 49:emerald
# Processing request number 50:upernavik
# Processing request number 51:poitiers
# Processing request number 52:terney
# Processing request number 53:linxia
# Processing request number 54:barrow
# Processing request number 55:okulovka
# Processing request number 56:mengcheng
# Processing request number 57:saskylakh
# Processing request number 58:hilo
# Processing request number 59:saint-augustin
# Processing request number 60:luderitz
# Processing request number 61:tiarei
# Processing request number 62:ylivieska
# Processing request number 63:chokurdakh
# Processing request number 64:yellowknife
# Processing request number 65:butaritari
# Processing request number 66:kovdor
# Processing request number 67:hobart
# Processing request number 68:new norfolk
# Processing request number 69:cape town
# Processing request number 70:nikolskoye
# Processing request number 71:caravelas
# city not found. skipping...
# Processing request number 72:cidreira
# Processing request number 73:sioux lookout
# Processing request number 74:trinidad
# Processing request number 75:pokhara
# city not found. skipping...
# Processing request number 76:havoysund
# Processing request number 77:daltenganj
# Processing request number 78:thompson
# Processing request number 79:sorland
# Processing request number 80:inhambane
# city not found. skipping...
# Processing request number 81:east london
# Processing request number 82:eyl
# Processing request number 83:ribeira grande
# Processing request number 84:tazovskiy
# Processing request number 85:ahipara
# Processing request number 86:meadville
# Processing request number 87:port-gentil
# Processing request number 88:naze
# Processing request number 89:domoni
# Processing request number 90:colares
# city not found. skipping...
# Processing request number 91:douglas
# Processing request number 92:longyearbyen
# Processing request number 93:hamilton
# Processing request number 94:coquimbo
# Processing request number 95:maraba
# Processing request number 96:zhigansk
# Processing request number 97:san andres
# Processing request number 98:ayan
# Processing request number 99:albury
# city not found. skipping...
# Processing request number 100:luba
# Processing request number 101:ponta do sol
# Processing request number 102:bredasdorp
# Processing request number 103:northam
# Processing request number 104:anadyr
# Processing request number 105:tiksi
# Processing request number 106:matamoros
# Processing request number 107:sitka
# Processing request number 108:padang
# city not found. skipping...
# Processing request number 109:edson
# Processing request number 110:rocha
# Processing request number 111:sironj
# Processing request number 112:saint george
# Processing request number 113:gorontalo
# Processing request number 114:zavetnoye
# Processing request number 115:ambilobe
# Processing request number 116:nanortalik
# city not found. skipping...
# Processing request number 117:samarai
# city not found. skipping...
# city not found. skipping...
# Processing request number 118:chernyshevskiy
# Processing request number 119:tahoua
# Processing request number 120:yerbogachen
# Processing request number 121:pontianak
# Processing request number 122:marsh harbour
# Processing request number 123:kruisfontein
# Processing request number 124:klaksvik
# Processing request number 125:yaan
# Processing request number 126:kloulklubed
# Processing request number 127:the valley
# Processing request number 128:tuktoyaktuk
# Processing request number 129:carballo
# Processing request number 130:sungaipenuh
# Processing request number 131:cardston
# Processing request number 132:kaitangata
# Processing request number 133:westport
# Processing request number 134:huanren
# Processing request number 135:ios
# Processing request number 136:broome
# city not found. skipping...
# Processing request number 137:aginskoye
# Processing request number 138:yishui
# Processing request number 139:kidal
# Processing request number 140:cap malheureux
# Processing request number 141:raton
# Processing request number 142:kununurra
# Processing request number 143:okhotsk
# Processing request number 144:pisco
# Processing request number 145:kambove
# Processing request number 146:kitaibaraki
# city not found. skipping...
# Processing request number 147:khatanga
# Processing request number 148:tabou
# Processing request number 149:teixoso
# Processing request number 150:saint-louis
# Processing request number 151:portland
# city not found. skipping...
# Processing request number 152:margate
# Processing request number 153:port elizabeth
# Processing request number 154:guerrero negro
# Processing request number 155:iquira
# Processing request number 156:leningradskiy
# city not found. skipping...
# Processing request number 157:ternate
# Processing request number 158:tura
# Processing request number 159:port macquarie
# Processing request number 160:elizabeth city
# Processing request number 161:kijang
# Processing request number 162:cabo san lucas
# Processing request number 163:qaanaaq
# Processing request number 164:kangaatsiaq
# Processing request number 165:broken hill
# Processing request number 166:moron
# Processing request number 167:jingdezhen
# Processing request number 168:touros
# Processing request number 169:khorramabad
# Processing request number 170:carahue
# city not found. skipping...
# Processing request number 171:kerouane
# Processing request number 172:mount isa
# Processing request number 173:jinchang
# Processing request number 174:jijiga
# Processing request number 175:balikpapan
# Processing request number 176:trelew
# Processing request number 177:isabela
# Processing request number 178:cherskiy
# Processing request number 179:cockburn town
# Processing request number 180:san patricio
# Processing request number 181:kavaratti
# Processing request number 182:taltal
# Processing request number 183:high level
# Processing request number 184:haines junction
# Processing request number 185:kenai
# Processing request number 186:muroto
# Processing request number 187:eldoret
# Processing request number 188:boden
# Processing request number 189:camalu
# Processing request number 190:aloleng
# Processing request number 191:beyneu
# Processing request number 192:vao
# Processing request number 193:murgab
# Processing request number 194:zella-mehlis
# Processing request number 195:gangarampur
# Processing request number 196:katsuura
# Processing request number 197:avera
# Processing request number 198:paamiut
# city not found. skipping...
# Processing request number 199:lianzhou
# Processing request number 200:avarua
# Processing request number 201:georgetown
# Processing request number 202:richards bay
# Processing request number 203:kapaa
# Processing request number 204:severodvinsk
# city not found. skipping...
# Processing request number 205:shumskiy
# Processing request number 206:soyaux
# Processing request number 207:carnarvon
# city not found. skipping...
# Processing request number 208:arriaga
# Processing request number 209:kamyshin
# Processing request number 210:peleduy
# Processing request number 211:karratha
# Processing request number 212:rio gallegos
# Processing request number 213:porangatu
# Processing request number 214:ochakiv
# Processing request number 215:qaqortoq
# Processing request number 216:bathsheba
# Processing request number 217:lebedyn
# Processing request number 218:thinadhoo
# Processing request number 219:srednekolymsk
# Processing request number 220:mul
# Processing request number 221:manaure
# Processing request number 222:vahan
# city not found. skipping...
# Processing request number 223:mogadishu
# Processing request number 224:lagoa
# Processing request number 225:rawlins
# Processing request number 226:huilong
# Processing request number 227:tolga
# Processing request number 228:maniitsoq
# Processing request number 229:mount gambier
# Processing request number 230:bengkulu
# city not found. skipping...
# Processing request number 231:neryungri
# Processing request number 232:bitung
# Processing request number 233:dauriya
# city not found. skipping...
# Processing request number 234:eureka
# Processing request number 235:bunbury
# Processing request number 236:mecca
# Processing request number 237:sao filipe
# Processing request number 238:havre-saint-pierre
# Processing request number 239:kizema
# Processing request number 240:presidencia roque saenz pena
# Processing request number 241:trofaiach
# Processing request number 242:tilichiki
# Processing request number 243:nyurba
# Processing request number 244:fortuna
# Processing request number 245:huarmey
# Processing request number 246:yeppoon
# Processing request number 247:ponta delgada
# Processing request number 248:duzce
# Processing request number 249:ratangarh
# Processing request number 250:urumqi
# Processing request number 251:faya
# Processing request number 252:zhezkazgan
# Processing request number 253:marathon
# Processing request number 254:alice springs
# Processing request number 255:roald
# Processing request number 256:castro
# Processing request number 257:kapit
# Processing request number 258:hovd
# Processing request number 259:bairnsdale
# Processing request number 260:nouadhibou
# Processing request number 261:naryan-mar
# Processing request number 262:aksu
# Processing request number 263:hofn
# Processing request number 264:dingle
# Processing request number 265:raudeberg
# Processing request number 266:yar-sale
# Processing request number 267:hereford
# Processing request number 268:navahrudak
# Processing request number 269:euclides da cunha
# Processing request number 270:lakatoro
# city not found. skipping...
# Processing request number 271:togur
# Processing request number 272:sahuaripa
# Processing request number 273:damara
# Processing request number 274:bambous virieux
# Processing request number 275:konevo
# Processing request number 276:tasiilaq
# Processing request number 277:san ramon
# Processing request number 278:narsaq
# Processing request number 279:turayf
# Processing request number 280:puerto ayora
# Processing request number 281:balkanabat
# Processing request number 282:dolores
# Processing request number 283:mackay
# Processing request number 284:acajutla
# Processing request number 285:lavrentiya
# Processing request number 286:victoria
# Processing request number 287:les cayes
# Processing request number 288:ginir
# Processing request number 289:dogondoutchi
# Processing request number 290:gemena
# Processing request number 291:rypefjord
# Processing request number 292:brae
# Processing request number 293:ilulissat
# Processing request number 294:bethel
# city not found. skipping...
# Processing request number 295:joensuu
# city not found. skipping...
# Processing request number 296:nome
# Processing request number 297:norsup
# Processing request number 298:la ronge
# Processing request number 299:arraial do cabo
# Processing request number 300:clonakilty
# Processing request number 301:petropavlovsk-kamchatskiy
# city not found. skipping...
# Processing request number 302:oranjemund
# Processing request number 303:gat
# Processing request number 304:severo-kurilsk
# Processing request number 305:povorino
# Processing request number 306:sao gabriel da cachoeira
# Processing request number 307:kirovsk
# Processing request number 308:asau
# Processing request number 309:adrar
# Processing request number 310:krasnoselkup
# Processing request number 311:korla
# Processing request number 312:praya
# city not found. skipping...
# Processing request number 313:beringovskiy
# Processing request number 314:takab
# Processing request number 315:jadu
# Processing request number 316:sechura
# Processing request number 317:belmonte
# Processing request number 318:tholen
# Processing request number 319:mananara
# Processing request number 320:ulladulla
# city not found. skipping...
# Processing request number 321:hami
# Processing request number 322:kiama
# Processing request number 323:svetlaya
# Processing request number 324:baracoa
# city not found. skipping...
# city not found. skipping...
# Processing request number 325:bongouanou
# city not found. skipping...
# Processing request number 326:pimentel
# Processing request number 327:mayumba
# Processing request number 328:plymouth
# Processing request number 329:sao joao da barra
# Processing request number 330:dunedin
# Processing request number 331:kaduqli
# Processing request number 332:bethanien
# Processing request number 333:saurimo
# Processing request number 334:roma
# Processing request number 335:fairbanks
# Processing request number 336:baena
# Processing request number 337:akdepe
# Processing request number 338:port hueneme
# Processing request number 339:burnie
# city not found. skipping...
# Processing request number 340:corinto
# Processing request number 341:henties bay
# Processing request number 342:constitucion
# Processing request number 343:plainview
# city not found. skipping...
# Processing request number 344:varnavino
# Processing request number 345:pevek
# Processing request number 346:gazanjyk
# city not found. skipping...
# Processing request number 347:preobrazheniye
# Processing request number 348:jalu
# Processing request number 349:angoche
# Processing request number 350:gizo
# Processing request number 351:batagay-alyta
# Processing request number 352:husavik
# Processing request number 353:muros
# Processing request number 354:geraldton
# Processing request number 355:brooks
# Processing request number 356:manitouwadge
# Processing request number 357:phayao
# city not found. skipping...
# Processing request number 358:haimen
# Processing request number 359:kouango
# Processing request number 360:ciudad bolivar
# Processing request number 361:taoudenni
# Processing request number 362:cayenne
# Processing request number 363:schwaz
# Processing request number 364:uhlove
# Processing request number 365:zbarazh
# Processing request number 366:tete
# Processing request number 367:erenhot
# Processing request number 368:guarapari
# Processing request number 369:hasaki
# Processing request number 370:cairns
# Processing request number 371:rorvik
# Processing request number 372:orcopampa
# Processing request number 373:hearst
# city not found. skipping...
# Processing request number 374:komsomolskiy
# Processing request number 375:ancud
# city not found. skipping...
# Processing request number 376:sehithwa
# Processing request number 377:bayburt
# Processing request number 378:fare
# Processing request number 379:pitrufquen
# Processing request number 380:norman wells
# Processing request number 381:port hardy
# Processing request number 382:waipawa
# Processing request number 383:yarada
# Processing request number 384:sola
# Processing request number 385:ukiah
# Processing request number 386:olafsvik
# Processing request number 387:suntar
# Processing request number 388:bela
# Processing request number 389:clarence town
# Processing request number 390:cuenca
# Processing request number 391:gravelbourg
# Processing request number 392:rizhao
# Processing request number 393:gillette
# Processing request number 394:sovetskiy
# Processing request number 395:san felipe
# city not found. skipping...
# Processing request number 396:ozernovskiy
# Processing request number 397:chuy
# Processing request number 398:champerico
# Processing request number 399:clyde river
# Processing request number 400:kashi
# Processing request number 401:eucaliptus
# Processing request number 402:zhengjiatun
# Processing request number 403:tautira
# Processing request number 404:sumter
# Processing request number 405:victor harbor
# Processing request number 406:kaili
# Processing request number 407:aquidauana
# Processing request number 408:namibe
# Processing request number 409:boende
# Processing request number 410:bukama
# Processing request number 411:kandrian
# Processing request number 412:takapau
# Processing request number 413:sol-iletsk
# Processing request number 414:lakhdenpokhya
# Processing request number 415:ola
# Processing request number 416:itoman
# Processing request number 417:camacha
# Processing request number 418:koson
# Processing request number 419:pafos
# city not found. skipping...
# Processing request number 420:nuuk
# Processing request number 421:verkh-chebula
# Processing request number 422:roros
# Processing request number 423:lewiston
# Processing request number 424:biak
# Processing request number 425:ghanzi
# Processing request number 426:trapani
# Processing request number 427:salalah
# Processing request number 428:lata
# Processing request number 429:aykhal
# Processing request number 430:gravdal
# Processing request number 431:sistranda
# Processing request number 432:port blair
# Processing request number 433:koslan
# Processing request number 434:aitape
# Processing request number 435:laguna de perlas
# Processing request number 436:mutis
# Processing request number 437:fengzhen
# Processing request number 438:vung tau
# Processing request number 439:gualeguay
# Processing request number 440:yashan
# Processing request number 441:quelimane
# Processing request number 442:mahon
# Processing request number 443:pacific grove
# Processing request number 444:evensk
# Processing request number 445:souillac
# Processing request number 446:zvenyhorodka
# Processing request number 447:marabba
# Processing request number 448:luena
# Processing request number 449:mayo
# Processing request number 450:merritt island
# Processing request number 451:sabya
# Processing request number 452:socorro
# Processing request number 453:izhmorskiy
# Processing request number 454:acapulco
# Processing request number 455:praia da vitoria
# Processing request number 456:outjo
# Processing request number 457:lazaro cardenas
# Processing request number 458:pangkalanbuun
# Processing request number 459:ishigaki
# Processing request number 460:alihe
# Processing request number 461:yarovoye
# Processing request number 462:nioro
# city not found. skipping...
# Processing request number 463:teruel
# Processing request number 464:ulaanbaatar
# Processing request number 465:kantunilkin
# Processing request number 466:puerto carreno
# Processing request number 467:coahuayana
# Processing request number 468:birao
# Processing request number 469:calama
# Processing request number 470:vytegra
# Processing request number 471:horki
# Processing request number 472:praxedis guerrero
# Processing request number 473:methoni
# Processing request number 474:kabalo
# Processing request number 475:solnechnyy
# Processing request number 476:hobyo
# Processing request number 477:ngaoundere
# Processing request number 478:chotila
# city not found. skipping...
# Processing request number 479:ouesso
# Processing request number 480:aswan
# Processing request number 481:gambo
# Processing request number 482:labrea
# Processing request number 483:russell
# Processing request number 484:whitehorse
# Processing request number 485:kaihua
# Processing request number 486:khuzhir
# Processing request number 487:bandraboua
# Processing request number 488:churapcha
# Processing request number 489:perth
# Processing request number 490:kingman
# Processing request number 491:dossor
# Processing request number 492:lielvarde
# Processing request number 493:okakarara
# Processing request number 494:saint-leu
# Processing request number 495:provideniya
# Processing request number 496:meulaboh
# Processing request number 497:tual
# Processing request number 498:vrangel
# Processing request number 499:los llanos de aridane
# Processing request number 500:yambio
# Processing request number 501:grindavik
# Processing request number 502:omsukchan
# Processing request number 503:san cristobal
# Processing request number 504:letlhakane
# Processing request number 505:gamba
# Processing request number 506:aksarka
# city not found. skipping...
# Processing request number 507:wajima
# city not found. skipping...
# Processing request number 508:kemijarvi
# Processing request number 509:aldan
# Processing request number 510:abaza
# Processing request number 511:simao
# Processing request number 512:haradok
# Processing request number 513:karpogory
# Processing request number 514:arman
# Processing request number 515:hue
# Processing request number 516:porto empedocle
# Processing request number 517:bolpur
# Processing request number 518:sturgis
# Processing request number 519:graham
# Processing request number 520:baykit
# Processing request number 521:san juan
# Processing request number 522:malanville
# Processing request number 523:qeshm
# Processing request number 524:shu
# Processing request number 525:gibsons
# Processing request number 526:sacama
# Processing request number 527:lubango
# Processing request number 528:bagotville
# Processing request number 529:poya
# Processing request number 530:kadoshkino
# Processing request number 531:vinh
# Processing request number 532:saldanha
# Processing request number 533:amga
# Processing request number 534:vila franca do campo
# Processing request number 535:smolenka
# Processing request number 536:vengurla
# Processing request number 537:flinders
# Processing request number 538:berlevag
# Processing request number 539:trat
# Processing request number 540:barra da estiva
# Processing request number 541:circleville
# Processing request number 542:guasdualito
# Processing request number 543:northwich
# Processing request number 544:beisfjord
# Processing request number 545:bereda
# Processing request number 546:labuan
# city not found. skipping...
# Processing request number 547:portobelo
# Processing request number 548:treinta y tres
# Processing request number 549:salaverry
# Processing request number 550:lethem
# city not found. skipping...
# Processing request number 551:dhidhdhoo
# Processing request number 552:marsa matruh
# Processing request number 553:antofagasta
# Processing request number 554:ugoofaaru
# []

# %%
#construct a DataFrame for weather data
weather_data_df = pd.DataFrame({"City Name": city_name, "Cloudiness": cloud, "Country": country, "Date": date, "Humidity": hum, "Lat": lat, "Lng": lng, "Max Temp": max_temp, "Wind Speed": wind_speed})
weather_data_df.head()
# Out:
#        City Name  Cloudiness Country        Date  Humidity      Lat       Lng  \
# 0          Bluff          89      NZ  1618522387        89 -46.6000  168.3333
# 1  Berdigestyakh          95      RU  1618522387        98  62.0989  126.6992
# 2   Punta Arenas          40      CL  1618522387        71 -53.1500  -70.9167
# 3         Torbay          90      CA  1618522388       100  47.6666  -52.7314
# 4  Mar del Plata           0      AR  1618522388        77 -38.0023  -57.5575
#
#    Max Temp  Wind Speed
# 0    283.71        4.02
# 1    264.10        1.46
# 2    284.15        4.12
# 3    273.71        8.75
# 4    294.26        4.12

# %%
#export the DataFrame to a csv
weather_data_df.to_csv(output_data_file)
