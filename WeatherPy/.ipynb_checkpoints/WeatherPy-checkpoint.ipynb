# %%
#dependencies and setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

#api key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

#output CSV
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
 # List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 629

# %%
#lists for storage
responses = []
city_id = []
city_name = []
cloud = []
country = []
date = []
hum = []
lat = []
lng = []
max_temp = []
wind_speed = []

r_num = 1
#build url and query_url
url = "http://api.openweathermap.org/data/2.5/weather?"
for city in cities:
    #query_url = url + "appid=" + api_key + "&q=" + city
    #weather_data = requests.get(query_url)
    try:
        query_url = url + "appid=" + api_key + "&q=" + city
        weather_data = requests.get(query_url)
        city_name.append(weather_data.json()['name'])
        cloud.append(weather_data.json()['clouds']['all'])
        country.append(weather_data.json()['sys']['country'])
        date.append(weather_data.json()['dt'])
        hum.append(weather_data.json()['main']['humidity'])
        lat.append(weather_data.json()['coord']['lat'])
        lng.append(weather_data.json()['coord']['lon'])
        max_temp.append(weather_data.json()['main']['temp_max'])
        wind_speed.append(weather_data.json()['wind']['speed'])
        print(f"Processing request number {r_num}:{city}")
        r_num = r_num + 1
    except KeyError:
        print("city not found. skipping...")
    #print(f"Processing request number {r_num}:{city}")
    #r_num = r_num + 1
    
weather_json = weather_data.json()
print(responses)
# Out:
# Processing request number 1:ierissos
# Processing request number 2:hilo
# Processing request number 3:maningrida
# Processing request number 4:albany
# Processing request number 5:hobart
# Processing request number 6:hermanus
# Processing request number 7:murgab
# Processing request number 8:yellowknife
# Processing request number 9:dikson
# Processing request number 10:chapais
# Processing request number 11:castro
# Processing request number 12:leningradskiy
# Processing request number 13:tiksi
# Processing request number 14:tuktoyaktuk
# Processing request number 15:barrow
# city not found. skipping...
# Processing request number 16:jamestown
# Processing request number 17:yanji
# Processing request number 18:afua
# Processing request number 19:punta arenas
# Processing request number 20:bengkulu
# city not found. skipping...
# Processing request number 21:ancud
# Processing request number 22:tecoanapa
# Processing request number 23:hambantota
# Processing request number 24:ibb
# Processing request number 25:madang
# Processing request number 26:puerto ayora
# Processing request number 27:vaini
# Processing request number 28:mar del plata
# Processing request number 29:port elizabeth
# Processing request number 30:saint george
# Processing request number 31:upernavik
# Processing request number 32:kalvarija
# Processing request number 33:busselton
# city not found. skipping...
# Processing request number 34:nikolskoye
# Processing request number 35:bluff
# Processing request number 36:chapleau
# city not found. skipping...
# Processing request number 37:santa maria
# Processing request number 38:turukhansk
# Processing request number 39:dzhebariki-khaya
# Processing request number 40:fonte boa
# Processing request number 41:rikitea
# Processing request number 42:codrington
# Processing request number 43:victoria point
# Processing request number 44:yanam
# Processing request number 45:mogadishu
# city not found. skipping...
# Processing request number 46:bambanglipuro
# Processing request number 47:merauke
# Processing request number 48:coquimbo
# Processing request number 49:thompson
# Processing request number 50:saint-philippe
# Processing request number 51:makat
# city not found. skipping...
# Processing request number 52:staryy nadym
# Processing request number 53:kodinsk
# Processing request number 54:kununurra
# Processing request number 55:grand forks
# Processing request number 56:kapaa
# city not found. skipping...
# Processing request number 57:pilar
# Processing request number 58:tilichiki
# Processing request number 59:bambous virieux
# city not found. skipping...
# Processing request number 60:fare
# Processing request number 61:nambour
# Processing request number 62:kitui
# Processing request number 63:luderitz
# Processing request number 64:otradnoye
# Processing request number 65:tual
# Processing request number 66:sergeyevka
# Processing request number 67:atuona
# Processing request number 68:srednekolymsk
# Processing request number 69:mataura
# Processing request number 70:kahului
# Processing request number 71:husavik
# Processing request number 72:paamiut
# Processing request number 73:ushuaia
# Processing request number 74:gubkinskiy
# Processing request number 75:grand gaube
# Processing request number 76:bafoulabe
# Processing request number 77:east london
# city not found. skipping...
# Processing request number 78:torbay
# Processing request number 79:ballina
# city not found. skipping...
# Processing request number 80:qaanaaq
# Processing request number 81:pevek
# Processing request number 82:kitimat
# Processing request number 83:anshun
# Processing request number 84:portland
# Processing request number 85:timmins
# Processing request number 86:teya
# Processing request number 87:avarua
# Processing request number 88:san quintin
# Processing request number 89:ibotirama
# Processing request number 90:saint anthony
# Processing request number 91:acarau
# city not found. skipping...
# Processing request number 92:saint-pierre
# Processing request number 93:bhilwara
# Processing request number 94:provideniya
# Processing request number 95:tasiilaq
# city not found. skipping...
# Processing request number 96:saskylakh
# Processing request number 97:katsuura
# Processing request number 98:new norfolk
# Processing request number 99:kostomuksha
# Processing request number 100:port alfred
# Processing request number 101:flinders
# Processing request number 102:belmonte
# Processing request number 103:faya
# Processing request number 104:kawalu
# city not found. skipping...
# Processing request number 105:lompoc
# Processing request number 106:carnarvon
# Processing request number 107:dingle
# Processing request number 108:noumea
# Processing request number 109:geraldton
# Processing request number 110:nelson bay
# Processing request number 111:butaritari
# Processing request number 112:altamont
# Processing request number 113:katobu
# Processing request number 114:chokurdakh
# Processing request number 115:upington
# Processing request number 116:malaut
# Processing request number 117:ritchie
# city not found. skipping...
# Processing request number 118:ribeira brava
# Processing request number 119:saldanha
# Processing request number 120:vigo
# Processing request number 121:kodiak
# Processing request number 122:xining
# Processing request number 123:lakes entrance
# Processing request number 124:takapau
# Processing request number 125:crixas
# Processing request number 126:tuy hoa
# Processing request number 127:aksu
# Processing request number 128:angoche
# city not found. skipping...
# city not found. skipping...
# Processing request number 129:abnub
# Processing request number 130:skjervoy
# Processing request number 131:gazimurskiy zavod
# Processing request number 132:caravelas
# Processing request number 133:gizo
# Processing request number 134:tres arroyos
# Processing request number 135:bredasdorp
# Processing request number 136:arman
# Processing request number 137:houma
# Processing request number 138:tukrah
# Processing request number 139:kindu
# Processing request number 140:murmashi
# Processing request number 141:salym
# Processing request number 142:souillac
# Processing request number 143:nacala
# Processing request number 144:puerto escondido
# Processing request number 145:port-cartier
# Processing request number 146:barcs
# Processing request number 147:kruisfontein
# Processing request number 148:korla
# Processing request number 149:haines junction
# Processing request number 150:aykhal
# Processing request number 151:tupik
# Processing request number 152:macapa
# Processing request number 153:oranjemund
# Processing request number 154:praia
# Processing request number 155:vila franca do campo
# Processing request number 156:lebu
# Processing request number 157:cape town
# Processing request number 158:nanortalik
# Processing request number 159:pascagoula
# Processing request number 160:honiara
# Processing request number 161:jumla
# Processing request number 162:vao
# Processing request number 163:north bend
# Processing request number 164:fairbanks
# Processing request number 165:bethel
# Processing request number 166:malanje
# Processing request number 167:dubbo
# Processing request number 168:padang
# Processing request number 169:necochea
# Processing request number 170:petropavlovsk-kamchatskiy
# Processing request number 171:yulara
# city not found. skipping...
# Processing request number 172:touros
# Processing request number 173:the valley
# Processing request number 174:issia
# Processing request number 175:severo-kurilsk
# Processing request number 176:ndele
# Processing request number 177:longyearbyen
# Processing request number 178:khani
# Processing request number 179:otjimbingwe
# Processing request number 180:laguna
# Processing request number 181:omboue
# Processing request number 182:college
# Processing request number 183:aklavik
# Processing request number 184:naples
# Processing request number 185:severnyy
# Processing request number 186:mumford
# Processing request number 187:san rafael
# Processing request number 188:riyadh
# Processing request number 189:sinnamary
# Processing request number 190:kampot
# Processing request number 191:agira
# Processing request number 192:tsiroanomandidy
# Processing request number 193:kudahuvadhoo
# Processing request number 194:beacon
# Processing request number 195:jiuquan
# Processing request number 196:lac du bonnet
# Processing request number 197:bogorodskoye
# Processing request number 198:quesnel
# Processing request number 199:nishihara
# Processing request number 200:lagoa
# Processing request number 201:peleduy
# Processing request number 202:katangli
# Processing request number 203:thunder bay
# Processing request number 204:khatanga
# Processing request number 205:rundu
# Processing request number 206:gopalpur
# Processing request number 207:rio grande
# Processing request number 208:komsomolskiy
# city not found. skipping...
# Processing request number 209:lashio
# city not found. skipping...
# Processing request number 210:kilindoni
# Processing request number 211:mount gambier
# Processing request number 212:kavaratti
# Processing request number 213:bestobe
# Processing request number 214:ahipara
# Processing request number 215:miraflores
# Processing request number 216:chapadinha
# Processing request number 217:hirara
# Processing request number 218:chuy
# Processing request number 219:mattru
# Processing request number 220:bratsk
# city not found. skipping...
# Processing request number 221:georgetown
# Processing request number 222:klaksvik
# city not found. skipping...
# Processing request number 223:batemans bay
# Processing request number 224:oistins
# Processing request number 225:naze
# Processing request number 226:yazman
# Processing request number 227:san cristobal
# Processing request number 228:rapid valley
# Processing request number 229:sisimiut
# Processing request number 230:mitu
# Processing request number 231:lima
# Processing request number 232:zychlin
# Processing request number 233:abu kamal
# Processing request number 234:wawa
# Processing request number 235:arraial do cabo
# Processing request number 236:ust-tsilma
# Processing request number 237:faanui
# Processing request number 238:victoria
# Processing request number 239:miri
# Processing request number 240:kendari
# Processing request number 241:shache
# Processing request number 242:desaguadero
# Processing request number 243:ola
# Processing request number 244:sagbayan
# Processing request number 245:princeton
# Processing request number 246:vitim
# Processing request number 247:smyrna
# Processing request number 248:nuuk
# Processing request number 249:wenzhou
# Processing request number 250:fillmore
# Processing request number 251:fortuna
# Processing request number 252:cherskiy
# Processing request number 253:cairns
# Processing request number 254:urusha
# Processing request number 255:green valley
# Processing request number 256:ryotsu
# Processing request number 257:sibolga
# Processing request number 258:san patricio
# Processing request number 259:chiredzi
# Processing request number 260:labuhan
# Processing request number 261:vardo
# city not found. skipping...
# Processing request number 262:sitka
# Processing request number 263:galle
# Processing request number 264:la ronge
# Processing request number 265:montrose
# city not found. skipping...
# city not found. skipping...
# Processing request number 266:tucuman
# Processing request number 267:chavakkad
# Processing request number 268:el jicaro
# Processing request number 269:yaan
# Processing request number 270:vanimo
# Processing request number 271:chihuahua
# Processing request number 272:gustavo diaz ordaz
# city not found. skipping...
# Processing request number 273:sao filipe
# Processing request number 274:ewa beach
# Processing request number 275:kalmunai
# Processing request number 276:santa cruz
# Processing request number 277:amot
# Processing request number 278:ponta do sol
# Processing request number 279:salalah
# Processing request number 280:constitucion
# city not found. skipping...
# Processing request number 281:bubaque
# city not found. skipping...
# Processing request number 282:ulaangom
# Processing request number 283:dunedin
# Processing request number 284:malartic
# city not found. skipping...
# Processing request number 285:canutama
# Processing request number 286:ranau
# Processing request number 287:jiwani
# Processing request number 288:kota belud
# Processing request number 289:beloha
# city not found. skipping...
# Processing request number 290:bosaso
# city not found. skipping...
# Processing request number 291:vizinga
# Processing request number 292:okhotsk
# Processing request number 293:grindavik
# Processing request number 294:petropavlovka
# Processing request number 295:ribeira grande
# Processing request number 296:tuatapere
# city not found. skipping...
# Processing request number 297:kuching
# Processing request number 298:bardiyah
# Processing request number 299:santiago del estero
# Processing request number 300:bathsheba
# Processing request number 301:denpasar
# city not found. skipping...
# Processing request number 302:hofn
# Processing request number 303:narsaq
# Processing request number 304:shubarkuduk
# Processing request number 305:chicama
# Processing request number 306:port-gentil
# Processing request number 307:lorengau
# Processing request number 308:santa barbara
# Processing request number 309:pula
# Processing request number 310:pekan
# Processing request number 311:cayenne
# Processing request number 312:novikovo
# Processing request number 313:road town
# Processing request number 314:indianola
# Processing request number 315:nyahururu
# Processing request number 316:shieli
# Processing request number 317:merritt
# Processing request number 318:biu
# Processing request number 319:rusape
# Processing request number 320:illela
# Processing request number 321:praia da vitoria
# Processing request number 322:nanakuli
# Processing request number 323:semey
# Processing request number 324:ossora
# Processing request number 325:sorong
# Processing request number 326:shingu
# Processing request number 327:nome
# Processing request number 328:anstruther
# Processing request number 329:torrevieja
# Processing request number 330:zholymbet
# Processing request number 331:azul
# Processing request number 332:wanaka
# Processing request number 333:hakodate
# city not found. skipping...
# Processing request number 334:maniitsoq
# Processing request number 335:abu samrah
# Processing request number 336:terre-de-bas
# Processing request number 337:port macquarie
# Processing request number 338:pisco
# Processing request number 339:baraboo
# Processing request number 340:psebay
# Processing request number 341:nizhniy kuranakh
# Processing request number 342:lavrentiya
# Processing request number 343:okha
# Processing request number 344:faro
# Processing request number 345:balaguer
# Processing request number 346:bom jesus
# Processing request number 347:terbuny
# Processing request number 348:yumen
# Processing request number 349:port blair
# Processing request number 350:tanout
# Processing request number 351:kondinskoye
# Processing request number 352:iqaluit
# Processing request number 353:shugurovo
# Processing request number 354:stavrovo
# Processing request number 355:inta
# Processing request number 356:yar-sale
# Processing request number 357:kotelnich
# Processing request number 358:kastrakion
# Processing request number 359:ilulissat
# Processing request number 360:isangel
# Processing request number 361:bonavista
# Processing request number 362:visby
# Processing request number 363:muros
# Processing request number 364:alpena
# Processing request number 365:whitehorse
# Processing request number 366:dabat
# Processing request number 367:bontang
# Processing request number 368:sao gabriel da cachoeira
# Processing request number 369:samoded
# Processing request number 370:jieshi
# Processing request number 371:port moresby
# Processing request number 372:dalby
# Processing request number 373:lasa
# Processing request number 374:kayerkan
# Processing request number 375:adeje
# Processing request number 376:conakry
# Processing request number 377:stornoway
# Processing request number 378:tefe
# Processing request number 379:hasaki
# Processing request number 380:kyshtovka
# Processing request number 381:santa clara
# Processing request number 382:latung
# Processing request number 383:sept-iles
# Processing request number 384:yakeshi
# Processing request number 385:manavalakurichi
# Processing request number 386:dingli
# Processing request number 387:asau
# Processing request number 388:makakilo city
# Processing request number 389:umm lajj
# Processing request number 390:shimoda
# city not found. skipping...
# Processing request number 391:westport
# Processing request number 392:puerto madryn
# Processing request number 393:roquetas de mar
# Processing request number 394:hami
# Processing request number 395:ugoofaaru
# Processing request number 396:mpongwe
# Processing request number 397:sandy bay
# Processing request number 398:bandarbeyla
# Processing request number 399:felanitx
# Processing request number 400:bilibino
# Processing request number 401:atherton
# Processing request number 402:pochutla
# Processing request number 403:adre
# Processing request number 404:atambua
# Processing request number 405:ketchikan
# Processing request number 406:kijang
# Processing request number 407:namibe
# Processing request number 408:el zulia
# Processing request number 409:beira
# Processing request number 410:talaya
# Processing request number 411:wilmington
# city not found. skipping...
# Processing request number 412:flin flon
# Processing request number 413:waipawa
# Processing request number 414:turkistan
# Processing request number 415:nouadhibou
# Processing request number 416:badiraguato
# Processing request number 417:juegang
# Processing request number 418:kaitangata
# Processing request number 419:alice springs
# Processing request number 420:orumiyeh
# Processing request number 421:guaimaro
# Processing request number 422:scarborough
# Processing request number 423:menzelinsk
# Processing request number 424:estelle
# city not found. skipping...
# Processing request number 425:havelock
# Processing request number 426:marawi
# Processing request number 427:villa maria
# Processing request number 428:jackson
# Processing request number 429:port augusta
# Processing request number 430:pouembout
# Processing request number 431:jodhpur
# Processing request number 432:qasigiannguit
# Processing request number 433:serpa
# Processing request number 434:kemin
# Processing request number 435:nyurba
# Processing request number 436:meulaboh
# Processing request number 437:porto novo
# Processing request number 438:ust-nera
# Processing request number 439:gewane
# Processing request number 440:paita
# Processing request number 441:nybro
# Processing request number 442:alta floresta
# Processing request number 443:mirnyy
# Processing request number 444:chernyshevskiy
# Processing request number 445:calvia
# Processing request number 446:shubarshi
# Processing request number 447:hithadhoo
# Processing request number 448:balykshi
# Processing request number 449:kudymkar
# Processing request number 450:cabedelo
# Processing request number 451:micomeseng
# Processing request number 452:novoulyanovsk
# Processing request number 453:meadow lake
# Processing request number 454:pahrump
# Processing request number 455:fayaoue
# Processing request number 456:esperance
# Processing request number 457:broome
# Processing request number 458:sao joao da barra
# Processing request number 459:arcachon
# Processing request number 460:gat
# Processing request number 461:thinadhoo
# Processing request number 462:busko-zdroj
# Processing request number 463:pontal
# Processing request number 464:kangaatsiaq
# Processing request number 465:bakchar
# Processing request number 466:zaliztsi
# Processing request number 467:ostrovnoy
# Processing request number 468:vredendal
# Processing request number 469:camacha
# Processing request number 470:poyarkovo
# Processing request number 471:gillette
# Processing request number 472:mahebourg
# Processing request number 473:nisia floresta
# Processing request number 474:pelym
# Processing request number 475:buta
# Processing request number 476:orange
# Processing request number 477:talnakh
# Processing request number 478:kristiansund
# Processing request number 479:vallenar
# Processing request number 480:kavieng
# Processing request number 481:vaasa
# Processing request number 482:yatou
# Processing request number 483:moyeuvre-grande
# Processing request number 484:kralendijk
# Processing request number 485:cordoba
# city not found. skipping...
# Processing request number 486:eregli
# Processing request number 487:cockburn town
# Processing request number 488:altay
# Processing request number 489:ust-koksa
# Processing request number 490:sambava
# Processing request number 491:nantucket
# Processing request number 492:storforshei
# Processing request number 493:katakwi
# Processing request number 494:tiverton
# Processing request number 495:walvis bay
# Processing request number 496:roswell
# Processing request number 497:mahanoro
# Processing request number 498:los llanos de aridane
# Processing request number 499:juneau
# Processing request number 500:dalvik
# Processing request number 501:north platte
# Processing request number 502:mayo
# Processing request number 503:boa vista
# Processing request number 504:quang ngai
# Processing request number 505:olafsvik
# Processing request number 506:te anau
# Processing request number 507:awbari
# Processing request number 508:bam
# Processing request number 509:rawson
# Processing request number 510:kuala terengganu
# Processing request number 511:awjilah
# Processing request number 512:dutlwe
# Processing request number 513:sogne
# Processing request number 514:matara
# Processing request number 515:plettenberg bay
# Processing request number 516:tabuk
# Processing request number 517:acapulco
# Processing request number 518:mehamn
# Processing request number 519:pangkalanbuun
# Processing request number 520:sydney
# Processing request number 521:poum
# Processing request number 522:tingo maria
# Processing request number 523:rehoboth
# Processing request number 524:norman wells
# Processing request number 525:kirakira
# Processing request number 526:trincomalee
# Processing request number 527:huatulco
# Processing request number 528:tottori
# Processing request number 529:cidreira
# Processing request number 530:margate
# Processing request number 531:korem
# Processing request number 532:rocha
# Processing request number 533:polson
# Processing request number 534:cabo san lucas
# Processing request number 535:beringovskiy
# Processing request number 536:lucera
# Processing request number 537:barsovo
# Processing request number 538:falakata
# Processing request number 539:kiruna
# city not found. skipping...
# Processing request number 540:krivosheino
# Processing request number 541:kupang
# Processing request number 542:bayangol
# Processing request number 543:barra patuca
# Processing request number 544:zhigansk
# city not found. skipping...
# Processing request number 545:thai binh
# Processing request number 546:divo
# city not found. skipping...
# Processing request number 547:launceston
# Processing request number 548:shasta lake
# Processing request number 549:santo antonio do ica
# Processing request number 550:hamilton
# Processing request number 551:coos bay
# Processing request number 552:cap malheureux
# Processing request number 553:pangnirtung
# Processing request number 554:mwingi
# Processing request number 555:qui nhon
# Processing request number 556:rockland
# Processing request number 557:abha
# Processing request number 558:sangar
# Processing request number 559:ucluelet
# Processing request number 560:daru
# Processing request number 561:saint-georges
# city not found. skipping...
# Processing request number 562:calais
# Processing request number 563:tura
# Processing request number 564:pital
# Processing request number 565:biak
# Processing request number 566:byron bay
# Processing request number 567:manokwari
# Processing request number 568:syke
# Processing request number 569:gomel
# Processing request number 570:marsassoum
# Processing request number 571:rabo de peixe
# city not found. skipping...
# Processing request number 572:ponta delgada
# Processing request number 573:chaozhou
# Processing request number 574:atasu
# Processing request number 575:atakpame
# Processing request number 576:aripuana
# Processing request number 577:rabaul
# Processing request number 578:berlevag
# city not found. skipping...
# Processing request number 579:pathein
# Processing request number 580:abu dhabi
# Processing request number 581:gamba
# Processing request number 582:lake city
# city not found. skipping...
# Processing request number 583:kerewan
# Processing request number 584:manta
# Processing request number 585:bugembe
# []

# %%
# Out:
# [0.89,
#  2.57,
#  3.39,
#  4.45,
#  4.12,
#  3.13,
#  3.24,
#  5.14,
#  7.7,
#  6.69,
#  2.56,
#  4.06,
#  1.21,
#  4.63,
#  2.57,
#  5.66,
#  1.88,
#  2.39,
#  5.66,
#  1.81,
#  1.54,
#  4.2,
#  4.5,
#  1.76,
#  0.34,
#  3.6,
#  2.57,
#  5.14,
#  4.63,
#  8.23,
#  0.95,
#  5.9,
#  4.33,
#  5,
#  1.34,
#  6.69,
#  2.06,
#  10.3,
#  1.09,
#  1.39,
#  3.46,
#  4.8,
#  2.35,
#  2.06,
#  6.46,
#  0.96,
#  4.71,
#  2.06,
#  1.54,
#  2.63,
#  3.81,
#  8.39,
#  6.67,
#  0.33,
#  4.63,
#  4.12,
#  2.06,
#  5.95,
#  3.6,
#  5.45,
#  0.45,
#  1.43,
#  0.37,
#  5,
#  3.96,
#  3.41,
#  9.29,
#  1.08,
#  1.34,
#  1.54,
#  6.17,
#  15.72,
#  3.09,
#  6.59,
#  1.34,
#  1.79,
#  7.2,
#  9.26,
#  2.16,
#  1.67,
#  9.01,
#  7.2,
#  2.68,
#  0.89,
#  6.17,
#  7.5,
#  1.54,
#  5.94,
#  2.23,
#  4.12,
#  5.91,
#  2.59,
#  5.73,
#  2.31,
#  10.29,
#  2.42,
#  3.6,
#  2.31,
#  2.6,
#  11.62,
#  4.12,
#  3.6,
#  2.57,
#  0.72,
#  2.57,
#  7.82,
#  1.76,
#  1.54,
#  3.6,
#  1.03,
#  4.14,
#  0.15,
#  1.01,
#  0.97,
#  0.51,
#  2.62,
#  1.03,
#  6.69,
#  5.14,
#  4.63,
#  6.69,
#  1.52,
#  6.82,
#  2.24,
#  2.07,
#  1.71,
#  2.58,
#  4,
#  6.17,
#  5.66,
#  1.65,
#  5.17,
#  3.92,
#  4.77,
#  5.66,
#  3.15,
#  5.14,
#  8.85,
#  1.52,
#  1,
#  3.7,
#  3.6,
#  2.67,
#  3.09,
#  7.2,
#  4.12,
#  1.79,
#  2.06,
#  0.51,
#  3.83,
#  0.78,
#  5.66,
#  2.98,
#  11.83,
#  4.63,
#  5.28,
#  10.8,
#  13,
#  2.06,
#  1.67,
#  2.3,
#  8.17,
#  2.06,
#  1.08,
#  0.45,
#  1.31,
#  2.57,
#  1.54,
#  1.34,
#  3,
#  2.57,
#  5.66,
#  4.63,
#  1.28,
#  8.64,
#  2.17,
#  12.86,
#  1.54,
#  3.99,
#  3.09,
#  3.39,
#  1.12,
#  3.6,
#  2.57,
#  3,
#  6.39,
#  4,
#  3.09,
#  5.24,
#  2.57,
#  8.49,
#  0.85,
#  3.28,
#  4.12,
#  5.19,
#  3.13,
#  6.78,
#  0.49,
#  5.14,
#  2.45,
#  2.27,
#  4.06,
#  5.14,
#  5.42,
#  2.56,
#  4.8,
#  2.57,
#  1.03,
#  0.63,
#  6.25,
#  2.06,
#  3.4,
#  3.58,
#  3.07,
#  2.57,
#  2.29,
#  7.64,
#  2.02,
#  4.07,
#  3,
#  1.54,
#  7.2,
#  1.79,
#  7.72,
#  4.65,
#  7.8,
#  7.72,
#  2.57,
#  8.55,
#  0.35,
#  4.63,
#  1.54,
#  2.47,
#  2.1,
#  5.66,
#  1.76,
#  5.38,
#  0.45,
#  1.58,
#  1.5,
#  4.54,
#  3.5,
#  3.18,
#  1.03,
#  5.14,
#  2.57,
#  2.57,
#  7.72,
#  0.71,
#  5.14,
#  1.71,
#  2.36,
#  1.54,
#  1.74,
#  1.79,
#  2.58,
#  1.44,
#  5.14,
#  2.59,
#  1.8,
#  2.06,
#  1.29,
#  1.79,
#  2.06,
#  11.32,
#  2.06,
#  1.03,
#  1.21,
#  2.25,
#  1.44,
#  3.09,
#  3.13,
#  5.74,
#  2.06,
#  5.34,
#  6.32,
#  1.54,
#  6.69,
#  3.6,
#  5.19,
#  5.61,
#  0.66,
#  0.89,
#  1.03,
#  1.29,
#  2.06,
#  5.19,
#  2.06,
#  3.43,
#  3.19,
#  2.11,
#  2.3,
#  13.89,
#  2.72,
#  4.12,
#  1.34,
#  0.97,
#  4.69,
#  2.68,
#  7.72,
#  2.06,
#  6.17,
#  6.69,
#  4.44,
#  7.2,
#  2.57,
#  1.25,
#  1.13,
#  3.09,
#  1.54,
#  8.23,
#  1.96,
#  4.63,
#  4.4,
#  4.88,
#  3.43,
#  1.03,
#  3.29,
#  2.97,
#  4.41,
#  2.52,
#  2.06,
#  3.32,
#  0.73,
#  4.16,
#  5.04,
#  5.66,
#  6.17,
#  2.68,
#  1.63,
#  1.34,
#  2.71,
#  1.61,
#  9.87,
#  3.37,
#  5.14,
#  0.45,
#  4.63,
#  5.66,
#  0.4,
#  1.96,
#  1.86,
#  4.15,
#  3.6,
#  6.17,
#  2.67,
#  3.15,
#  3.48,
#  2.33,
#  4.71,
#  5.64,
#  8.23,
#  2.27,
#  7.22,
#  5.55,
#  7.73,
#  4.82,
#  0.89,
#  2.57,
#  1.72,
#  2.57,
#  6.69,
#  4.36,
#  6.17,
#  2.06,
#  2.38,
#  2.32,
#  2.06,
#  1.88,
#  5.25,
#  8.75,
#  2.57,
#  2.06,
#  9.92,
#  2.06,
#  5.14,
#  8.75,
#  3.09,
#  2.57,
#  4.68,
#  4.63,
#  6.45,
#  7.2,
#  6.89,
#  1.54,
#  7.72,
#  1.43,
#  2.06,
#  4.04,
#  3.73,
#  4.63,
#  1.38,
#  4.12,
#  1.8,
#  3.31,
#  2.59,
#  2.06,
#  4.82,
#  7.2,
#  1.34,
#  0.45,
#  4.12,
#  5.01,
#  2.05,
#  4.12,
#  2.57,
#  3.63,
#  3.6,
#  3.17,
#  1.72,
#  2.57,
#  3.09,
#  3.6,
#  1.37,
#  9.26,
#  2.06,
#  3.74,
#  2.31,
#  4.63,
#  2.06,
#  2.57,
#  0.89,
#  2,
#  5.14,
#  4.63,
#  1.79,
#  0.89,
#  0.4,
#  2.57,
#  1.34,
#  7.9,
#  2.57,
#  1.54,
#  1.02,
#  2,
#  0.69,
#  6.69,
#  1.58,
#  2.22,
#  7.72,
#  6.69,
#  1.21,
#  2.82,
#  2.52,
#  2.24,
#  4.37,
#  0.87,
#  5,
#  4.19,
#  5.14,
#  2.16,
#  2,
#  4.12,
#  2.68,
#  2.34,
#  1.61,
#  4.12,
#  4.12,
#  5.66,
#  0.45,
#  2.95,
#  1.34,
#  2.57,
#  9.23,
#  3.42,
#  5.32,
#  2.24,
#  3.06,
#  7.72,
#  4.69,
#  2.06,
#  3.6,
#  6.69,
#  4.21,
#  0.76,
#  1.9,
#  8.91,
#  2.06,
#  3.35,
#  2.76,
#  2.06,
#  7.8,
#  1.34,
#  9.77,
#  4.12,
#  3.56,
#  4.12,
#  2.94,
#  0.24,
#  2.43,
#  6.69,
#  1.03,
#  1.92,
#  0.45,
#  5.03,
#  5.14,
#  1.4,
#  9.77,
#  1.35,
#  6.17,
#  3.6,
#  5.14,
#  6.17,
#  1.65,
#  10.02,
#  1.79,
#  4.3,
#  1.91,
#  2.85,
#  1.03,
#  4.38,
#  1.09,
#  4.63,
#  1.84,
#  0.65,
#  0.78,
#  2.06,
#  4.63,
#  0.44,
#  1.79,
#  3.07,
#  1.03,
#  4.79,
#  2.06,
#  1.84,
#  2.7,
#  4.12,
#  2.89,
#  7,
#  1.79,
#  2.67,
#  3.58,
#  1.34,
#  1.54,
#  3.89,
#  5.14,
#  5,
#  1.44,
#  4.12,
#  4.55,
#  2.62,
#  1.64,
#  4.54,
#  3.33,
#  2.57,
#  2.81,
#  2.57,
#  0.71,
#  1.37,
#  2.57,
#  2.06,
#  2.24,
#  3.09,
#  2.25,
#  1.34,
#  0.45,
#  2.57,
#  0.63,
#  1.03,
#  5.11,
#  9.26,
#  3.13,
#  2.55,
#  2.13,
#  1.87,
#  2.58,
#  1.68,
#  5.66,
#  1,
#  3.09,
#  4.63,
#  4.63,
#  3,
#  4.74,
#  2.47,
#  1,
#  1.16,
#  2.57,
#  2.88,
#  3.09,
#  2.77,
#  7.72,
#  6.17,
#  2.57,
#  2.12]
