# %%
#dependencies and setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

#api key
from config import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

#output CSV
output_data_file = "output_data_cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
 # List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 622

# %%
#lists for storage
responses = []
city_id = []
city_name = []
cloud = []
country = []
date = []
hum = []
lat = []
lng = []
max_temp = []
wind_speed = []

r_num = 1
#build url and query_url
url = "http://api.openweathermap.org/data/2.5/weather?"
for city in cities:
    try:
        query_url = url + "appid=" + weather_api_key + "&q=" + city
        weather_data = requests.get(query_url)
        city_name.append(weather_data.json()['name'])
        cloud.append(weather_data.json()['clouds']['all'])
        country.append(weather_data.json()['sys']['country'])
        date.append(weather_data.json()['dt'])
        hum.append(weather_data.json()['main']['humidity'])
        lat.append(weather_data.json()['coord']['lat'])
        lng.append(weather_data.json()['coord']['lon'])
        max_temp.append(weather_data.json()['main']['temp_max'])
        wind_speed.append(weather_data.json()['wind']['speed'])
        print(f"Processing request number {r_num}:{city}")
        r_num = r_num + 1
    except KeyError:
        print("city not found. skipping...")
# Out:
# Processing request number 1:punta arenas
# city not found. skipping...
# Processing request number 2:quelimane
# Processing request number 3:new norfolk
# Processing request number 4:castro
# Processing request number 5:saskylakh
# Processing request number 6:araceli
# Processing request number 7:solenzo
# Processing request number 8:atuona
# Processing request number 9:longyearbyen
# Processing request number 10:tampere
# Processing request number 11:victoria
# Processing request number 12:pokhara
# Processing request number 13:ribeira grande
# Processing request number 14:busselton
# Processing request number 15:soure
# Processing request number 16:makakilo city
# Processing request number 17:farafangana
# Processing request number 18:hermanus
# Processing request number 19:upernavik
# Processing request number 20:malakal
# Processing request number 21:carnarvon
# Processing request number 22:bluff
# Processing request number 23:biltine
# city not found. skipping...
# Processing request number 24:albany
# Processing request number 25:rikitea
# Processing request number 26:san cristobal
# Processing request number 27:malangwa
# Processing request number 28:leningradskiy
# city not found. skipping...
# Processing request number 29:arraial do cabo
# city not found. skipping...
# Processing request number 30:sawakin
# Processing request number 31:jamestown
# Processing request number 32:caloundra
# Processing request number 33:macaubas
# Processing request number 34:neyshabur
# Processing request number 35:hobart
# Processing request number 36:lorengau
# city not found. skipping...
# Processing request number 37:qaanaaq
# Processing request number 38:liberty
# Processing request number 39:saint-philippe
# Processing request number 40:brae
# Processing request number 41:moindou
# Processing request number 42:evensk
# Processing request number 43:torbay
# Processing request number 44:port alfred
# Processing request number 45:barcelona
# Processing request number 46:kempele
# Processing request number 47:dinguiraye
# Processing request number 48:kapaa
# Processing request number 49:jacqueville
# Processing request number 50:kenai
# Processing request number 51:mataura
# Processing request number 52:conceicao do araguaia
# Processing request number 53:fortuna
# Processing request number 54:muli
# Processing request number 55:norman wells
# Processing request number 56:mirnyy
# Processing request number 57:ewo
# Processing request number 58:pacific grove
# Processing request number 59:hervey bay
# Processing request number 60:eyl
# city not found. skipping...
# Processing request number 61:boa vista
# Processing request number 62:tateyama
# city not found. skipping...
# Processing request number 63:faanui
# Processing request number 64:teguise
# Processing request number 65:coquimbo
# Processing request number 66:dikson
# Processing request number 67:boende
# Processing request number 68:atikokan
# Processing request number 69:okhotsk
# Processing request number 70:east london
# Processing request number 71:ushuaia
# Processing request number 72:ixtapa
# city not found. skipping...
# Processing request number 73:pevek
# Processing request number 74:saint george
# city not found. skipping...
# Processing request number 75:borzya
# Processing request number 76:port hardy
# Processing request number 77:alappuzha
# Processing request number 78:vitim
# Processing request number 79:khatanga
# Processing request number 80:jiwani
# Processing request number 81:chadan
# Processing request number 82:hilo
# Processing request number 83:cape town
# Processing request number 84:puerto ayora
# Processing request number 85:isla mujeres
# Processing request number 86:itupiranga
# Processing request number 87:isangel
# Processing request number 88:biggar
# Processing request number 89:lasa
# Processing request number 90:talant
# Processing request number 91:ponta do sol
# Processing request number 92:lata
# Processing request number 93:nisia floresta
# Processing request number 94:nikolskoye
# Processing request number 95:laguna
# Processing request number 96:hualmay
# Processing request number 97:tuktoyaktuk
# Processing request number 98:bilma
# Processing request number 99:seoul
# Processing request number 100:bredasdorp
# Processing request number 101:mount gambier
# Processing request number 102:kaitangata
# Processing request number 103:dicamay
# Processing request number 104:montrose
# Processing request number 105:lac du bonnet
# Processing request number 106:bodden town
# Processing request number 107:campoverde
# Processing request number 108:sitka
# Processing request number 109:hobyo
# Processing request number 110:murgab
# Processing request number 111:kiunga
# Processing request number 112:vila do maio
# Processing request number 113:kodiak
# Processing request number 114:gornopravdinsk
# Processing request number 115:carnot
# Processing request number 116:nome
# Processing request number 117:ramotswa
# Processing request number 118:faya
# Processing request number 119:saint-augustin
# Processing request number 120:butaritari
# Processing request number 121:lipin bor
# Processing request number 122:sao joao da barra
# Processing request number 123:kulhudhuffushi
# Processing request number 124:yinchuan
# Processing request number 125:anloga
# Processing request number 126:nyurba
# city not found. skipping...
# city not found. skipping...
# Processing request number 127:katsuura
# Processing request number 128:thompson
# Processing request number 129:airai
# Processing request number 130:oeiras do para
# Processing request number 131:bedele
# Processing request number 132:mar del plata
# Processing request number 133:avarua
# Processing request number 134:chokurdakh
# Processing request number 135:ngorongoro
# Processing request number 136:georgetown
# Processing request number 137:boca do acre
# Processing request number 138:port-gentil
# Processing request number 139:djibo
# Processing request number 140:vaini
# Processing request number 141:palana
# Processing request number 142:northam
# Processing request number 143:edd
# Processing request number 144:necochea
# Processing request number 145:loiza
# Processing request number 146:najran
# Processing request number 147:visby
# Processing request number 148:imbituba
# Processing request number 149:hasaki
# Processing request number 150:byron bay
# city not found. skipping...
# Processing request number 151:coihaique
# Processing request number 152:barrow
# Processing request number 153:moyale
# Processing request number 154:lalgudi
# Processing request number 155:susanino
# Processing request number 156:pinheiro machado
# Processing request number 157:saldanha
# Processing request number 158:toppenish
# Processing request number 159:chuy
# Processing request number 160:kloulklubed
# Processing request number 161:khorramshahr
# Processing request number 162:kamenka
# Processing request number 163:bathsheba
# Processing request number 164:sur
# Processing request number 165:lebu
# Processing request number 166:kysyl-syr
# Processing request number 167:kaseda
# Processing request number 168:kimbe
# Processing request number 169:okha
# city not found. skipping...
# Processing request number 170:roald
# Processing request number 171:paamiut
# Processing request number 172:flers
# Processing request number 173:ribeira brava
# Processing request number 174:carauari
# Processing request number 175:esperance
# Processing request number 176:belmonte
# Processing request number 177:tazovskiy
# Processing request number 178:san fernando
# Processing request number 179:bekhtery
# Processing request number 180:cidreira
# Processing request number 181:ancud
# Processing request number 182:divnoye
# Processing request number 183:srednekolymsk
# Processing request number 184:hami
# Processing request number 185:princeton
# Processing request number 186:ghogha
# Processing request number 187:tiksi
# Processing request number 188:portland
# Processing request number 189:mahebourg
# Processing request number 190:ponta delgada
# Processing request number 191:ambon
# Processing request number 192:panama city
# Processing request number 193:geraldton
# Processing request number 194:umm kaddadah
# Processing request number 195:pimentel
# Processing request number 196:ypsonas
# Processing request number 197:deputatskiy
# Processing request number 198:mikhaylovka
# Processing request number 199:dawei
# Processing request number 200:charters towers
# Processing request number 201:kidal
# Processing request number 202:trinidad
# Processing request number 203:nanortalik
# Processing request number 204:saint-pierre
# Processing request number 205:bethel
# Processing request number 206:klaksvik
# Processing request number 207:praia da vitoria
# Processing request number 208:kavaratti
# Processing request number 209:akom
# Processing request number 210:padang
# Processing request number 211:chachapoyas
# Processing request number 212:gamba
# Processing request number 213:kurchum
# Processing request number 214:youghal
# Processing request number 215:pemba
# Processing request number 216:rosetta
# city not found. skipping...
# city not found. skipping...
# Processing request number 217:copiapo
# Processing request number 218:chicama
# Processing request number 219:yellowknife
# Processing request number 220:jiayuguan
# Processing request number 221:zapolyarnyy
# Processing request number 222:the valley
# Processing request number 223:chulman
# Processing request number 224:iqaluit
# Processing request number 225:kashmor
# city not found. skipping...
# Processing request number 226:navahrudak
# Processing request number 227:port elizabeth
# Processing request number 228:hailey
# Processing request number 229:sorong
# Processing request number 230:maldonado
# Processing request number 231:komsomolskiy
# Processing request number 232:cabedelo
# Processing request number 233:san patricio
# Processing request number 234:gat
# Processing request number 235:ayagoz
# Processing request number 236:champerico
# Processing request number 237:kabare
# Processing request number 238:noshiro
# Processing request number 239:mangrol
# Processing request number 240:tautira
# Processing request number 241:shelbyville
# Processing request number 242:jinchang
# Processing request number 243:yulara
# Processing request number 244:hithadhoo
# Processing request number 245:altoona
# Processing request number 246:cabo san lucas
# Processing request number 247:stokmarknes
# Processing request number 248:waipawa
# Processing request number 249:namwala
# Processing request number 250:hearst
# city not found. skipping...
# Processing request number 251:acapulco
# city not found. skipping...
# Processing request number 252:svetlaya
# city not found. skipping...
# Processing request number 253:atar
# Processing request number 254:vardo
# Processing request number 255:opuwo
# Processing request number 256:freeport
# Processing request number 257:goderich
# Processing request number 258:dunedin
# Processing request number 259:newark
# Processing request number 260:tezu
# Processing request number 261:bastia
# Processing request number 262:manokwari
# Processing request number 263:ahipara
# Processing request number 264:lexington
# Processing request number 265:batemans bay
# Processing request number 266:belo oriente
# Processing request number 267:caravelas
# Processing request number 268:osa
# Processing request number 269:maumere
# Processing request number 270:comodoro rivadavia
# city not found. skipping...
# city not found. skipping...
# Processing request number 271:dingle
# Processing request number 272:tilichiki
# Processing request number 273:walvis bay
# Processing request number 274:juneau
# Processing request number 275:norrtalje
# Processing request number 276:zinder
# Processing request number 277:santiago de cao
# Processing request number 278:coahuayana
# Processing request number 279:dakoro
# Processing request number 280:kuching
# Processing request number 281:krasnoborsk
# Processing request number 282:bridlington
# Processing request number 283:kushima
# Processing request number 284:port lincoln
# Processing request number 285:batsfjord
# Processing request number 286:werda
# Processing request number 287:nelson bay
# Processing request number 288:bandarbeyla
# Processing request number 289:ilulissat
# Processing request number 290:turbat
# city not found. skipping...
# city not found. skipping...
# city not found. skipping...
# Processing request number 291:tornio
# Processing request number 292:berlevag
# Processing request number 293:motihari
# Processing request number 294:kirensk
# Processing request number 295:cherskiy
# city not found. skipping...
# Processing request number 296:wanning
# Processing request number 297:zeya
# Processing request number 298:mullovka
# Processing request number 299:port macquarie
# Processing request number 300:port blair
# city not found. skipping...
# Processing request number 301:xining
# Processing request number 302:nuuk
# Processing request number 303:anadyr
# Processing request number 304:warrington
# Processing request number 305:kavieng
# Processing request number 306:jimenez
# Processing request number 307:chifeng
# Processing request number 308:homer
# Processing request number 309:oktyabrskiy
# Processing request number 310:tuatapere
# Processing request number 311:taltal
# Processing request number 312:bireun
# Processing request number 313:asfi
# Processing request number 314:foki
# Processing request number 315:ambilobe
# Processing request number 316:grindavik
# Processing request number 317:prince rupert
# Processing request number 318:muros
# Processing request number 319:camacupa
# Processing request number 320:olga
# Processing request number 321:ludvika
# Processing request number 322:ipixuna
# Processing request number 323:vermillion
# Processing request number 324:uray
# Processing request number 325:kishi
# Processing request number 326:zaragoza
# Processing request number 327:tasiilaq
# Processing request number 328:jawhar
# Processing request number 329:zilupe
# Processing request number 330:nyrob
# Processing request number 331:cienfuegos
# city not found. skipping...
# Processing request number 332:tarko-sale
# Processing request number 333:buala
# city not found. skipping...
# Processing request number 334:san policarpo
# Processing request number 335:bani
# Processing request number 336:upata
# Processing request number 337:pangkalanbuun
# Processing request number 338:liverpool
# Processing request number 339:severo-kurilsk
# Processing request number 340:ostrovnoy
# Processing request number 341:madanapalle
# Processing request number 342:kirakira
# Processing request number 343:samaniego
# city not found. skipping...
# Processing request number 344:nakhon thai
# Processing request number 345:viedma
# Processing request number 346:rocha
# Processing request number 347:ampanihy
# Processing request number 348:ballina
# Processing request number 349:aleksandrov gay
# Processing request number 350:clyde river
# Processing request number 351:shenjiamen
# Processing request number 352:wuwei
# Processing request number 353:luderitz
# Processing request number 354:darhan
# city not found. skipping...
# Processing request number 355:houma
# Processing request number 356:ituverava
# Processing request number 357:brownwood
# Processing request number 358:bambous virieux
# Processing request number 359:provideniya
# Processing request number 360:mollendo
# Processing request number 361:maues
# Processing request number 362:talnakh
# Processing request number 363:nybro
# Processing request number 364:ketchikan
# Processing request number 365:sungurlu
# Processing request number 366:saint-georges
# Processing request number 367:derzhavinsk
# Processing request number 368:inuvik
# Processing request number 369:kaeo
# Processing request number 370:flin flon
# Processing request number 371:karratha
# city not found. skipping...
# Processing request number 372:saint-paul
# Processing request number 373:vestmannaeyjar
# Processing request number 374:lompoc
# Processing request number 375:la tuque
# Processing request number 376:port hedland
# Processing request number 377:carlisle
# Processing request number 378:narsaq
# Processing request number 379:wahiawa
# Processing request number 380:snezhnogorsk
# Processing request number 381:kommunisticheskiy
# Processing request number 382:saint anthony
# Processing request number 383:sanming
# Processing request number 384:pochutla
# Processing request number 385:west plains
# Processing request number 386:chara
# Processing request number 387:matara
# Processing request number 388:camocim
# Processing request number 389:washougal
# Processing request number 390:aklavik
# Processing request number 391:baiquan
# Processing request number 392:bilibino
# Processing request number 393:tura
# Processing request number 394:chimbote
# Processing request number 395:ghanzi
# Processing request number 396:hambantota
# city not found. skipping...
# Processing request number 397:bowen
# city not found. skipping...
# Processing request number 398:san quintin
# Processing request number 399:antofagasta
# Processing request number 400:jalu
# Processing request number 401:shihezi
# Processing request number 402:sao filipe
# Processing request number 403:chacabuco
# Processing request number 404:shakhtinsk
# Processing request number 405:oksfjord
# Processing request number 406:mangai
# Processing request number 407:sao miguel do araguaia
# Processing request number 408:dicabisagan
# Processing request number 409:los alamos
# Processing request number 410:adolfo lopez mateos
# Processing request number 411:quatre cocos
# Processing request number 412:sechura
# Processing request number 413:camacha
# Processing request number 414:coari
# Processing request number 415:bay roberts
# Processing request number 416:marawi
# Processing request number 417:kalmunai
# Processing request number 418:benghazi
# Processing request number 419:ostersund
# Processing request number 420:bac lieu
# Processing request number 421:pundaguitan
# Processing request number 422:epe
# Processing request number 423:iquitos
# Processing request number 424:tessalit
# Processing request number 425:ranir bazar
# Processing request number 426:hay river
# Processing request number 427:oranjemund
# Processing request number 428:cayenne
# Processing request number 429:vostok
# Processing request number 430:dhidhdhoo
# Processing request number 431:shipunovo
# Processing request number 432:vila velha
# city not found. skipping...
# Processing request number 433:shambu
# Processing request number 434:souillac
# Processing request number 435:pauini
# city not found. skipping...
# Processing request number 436:kyabe
# Processing request number 437:fort nelson
# Processing request number 438:ilo
# Processing request number 439:alihe
# city not found. skipping...
# Processing request number 440:luanda
# Processing request number 441:payo
# Processing request number 442:ngunguru
# Processing request number 443:itarema
# Processing request number 444:general cepeda
# Processing request number 445:port hawkesbury
# Processing request number 446:afonso bezerra
# Processing request number 447:siderno
# Processing request number 448:luganville
# Processing request number 449:kasongo-lunda
# Processing request number 450:muroto
# Processing request number 451:sale
# Processing request number 452:newala
# city not found. skipping...
# city not found. skipping...
# Processing request number 453:fukue
# Processing request number 454:katobu
# Processing request number 455:saint-joseph
# city not found. skipping...
# Processing request number 456:muravlenko
# Processing request number 457:shu
# Processing request number 458:safranbolu
# Processing request number 459:viseu
# Processing request number 460:anshun
# Processing request number 461:bo phloi
# Processing request number 462:itacoatiara
# Processing request number 463:volchikha
# Processing request number 464:verkhnyaya inta
# Processing request number 465:altamont
# Processing request number 466:rio claro
# Processing request number 467:kodinsk
# city not found. skipping...
# Processing request number 468:pangnirtung
# Processing request number 469:soe
# Processing request number 470:wencheng
# Processing request number 471:te anau
# Processing request number 472:chiang khong
# Processing request number 473:dromolaxia
# Processing request number 474:san jose
# Processing request number 475:san lorenzo de el escorial
# Processing request number 476:shingu
# Processing request number 477:elko
# Processing request number 478:hanchuan
# Processing request number 479:canico
# Processing request number 480:nouakchott
# city not found. skipping...
# Processing request number 481:bereda
# Processing request number 482:bushenyi
# Processing request number 483:sinnamary
# Processing request number 484:gwadar
# Processing request number 485:kahului
# Processing request number 486:tucurui
# Processing request number 487:moose factory
# Processing request number 488:chizhou
# Processing request number 489:bengkulu
# Processing request number 490:ochamchira
# Processing request number 491:petukhovo
# Processing request number 492:mount isa
# Processing request number 493:hare bay
# Processing request number 494:taoudenni
# city not found. skipping...
# city not found. skipping...
# Processing request number 495:kouango
# Processing request number 496:shimoda
# Processing request number 497:saint-felicien
# Processing request number 498:manzhouli
# Processing request number 499:harper
# Processing request number 500:khasan
# Processing request number 501:palauig
# Processing request number 502:margate
# city not found. skipping...
# Processing request number 503:gondanglegi
# Processing request number 504:haines junction
# Processing request number 505:shelburne
# Processing request number 506:zharkent
# Processing request number 507:hilton head island
# Processing request number 508:boksitogorsk
# Processing request number 509:natal
# Processing request number 510:aykhal
# Processing request number 511:san luis
# Processing request number 512:yambio
# Processing request number 513:nampula
# Processing request number 514:calabozo
# Processing request number 515:harlingen
# Processing request number 516:imeni babushkina
# Processing request number 517:halden
# Processing request number 518:panjakent
# Processing request number 519:linjiang
# Processing request number 520:lagoa
# Processing request number 521:maniitsoq
# Processing request number 522:half moon bay
# city not found. skipping...
# Processing request number 523:havoysund
# Processing request number 524:sao jose da coroa grande
# Processing request number 525:ucluelet
# Processing request number 526:lukovetskiy
# Processing request number 527:abu kamal
# Processing request number 528:umba
# Processing request number 529:thongwa
# Processing request number 530:ovsyanka
# Processing request number 531:vao
# Processing request number 532:tourlaville
# Processing request number 533:melfi
# Processing request number 534:lavrentiya
# Processing request number 535:bichura
# Processing request number 536:rosarito
# Processing request number 537:adrar
# Processing request number 538:ventspils
# Processing request number 539:nazare
# Processing request number 540:grand-santi
# Processing request number 541:knysna
# Processing request number 542:taitung
# Processing request number 543:lufilufi
# Processing request number 544:boddam
# city not found. skipping...
# Processing request number 545:narovchat
# Processing request number 546:waimalu
# Processing request number 547:guhagar
# Processing request number 548:baykit
# Processing request number 549:santa cruz
# Processing request number 550:verkhnevilyuysk
# city not found. skipping...
# Processing request number 551:puerto del rosario
# Processing request number 552:kargopol
# Processing request number 553:poum
# Processing request number 554:belyy yar
# Processing request number 555:gorontalo
# Processing request number 556:tres arroyos
# Processing request number 557:panaba
# Processing request number 558:salima
# Processing request number 559:tigil
# Processing request number 560:calatayud
# Processing request number 561:akyab
# Processing request number 562:umuahia
# Processing request number 563:salym
# Processing request number 564:henties bay
# Processing request number 565:bulawayo
# Processing request number 566:abha
# city not found. skipping...
# Processing request number 567:husavik
# Processing request number 568:qaqortoq
# Processing request number 569:katherine
# Processing request number 570:samarai
# Processing request number 571:la romana
# Processing request number 572:mayo
# Processing request number 573:aloleng
# Processing request number 574:zyryanskoye

# %%
#construct a DataFrame for weather data
weather_data_df = pd.DataFrame({"City Name": city_name, "Cloudiness": cloud, "Country": country, "Date": date, "Humidity": hum, "Lat": lat, "Lng": lng, "Max Temp": max_temp, "Wind Speed": wind_speed})
weather_data_df.head()
# Out:
#       City Name  Cloudiness Country        Date  Humidity      Lat       Lng  \
# 0  Punta Arenas          75      CL  1618528021        81 -53.1500  -70.9167
# 1     Quelimane           0      MZ  1618528296        88 -17.8786   36.8883
# 2   New Norfolk          39      AU  1618528059        78 -42.7826  147.0587
# 3        Castro          92      BR  1618528014        83 -24.7911  -50.0119
# 4     Saskylakh          97      RU  1618528036        99  71.9167  114.0833
#
#    Max Temp  Wind Speed
# 0    282.15        3.09
# 1    297.15        2.06
# 2    284.82        0.89
# 3    289.57        2.89
# 4    253.63        2.82

# %%
#export the DataFrame to a csv
weather_data_df.to_csv(output_data_file)
